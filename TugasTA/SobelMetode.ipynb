# %% [markdown]
# # Penerapan Metode Sobel untuk penerapan deteksi jawabam LJK

# %% [markdown]
# Citra Gambar LJK yang telah di isi
#
# <img src="lkj.jpg">
#
#
#
# Sampel Percobaan
# <img src="lkjsampel.jpg">

# %%
# Implementasi Metode Sobel 

import numpy as np
import cv2
from matplotlib import pyplot as plt
import copy
import imageio
np.set_printoptions(threshold=np.inf)

img_original = imageio.imread("lkjsampel.jpg")
def sobelOperator(img):
    container = np.copy(img)
    size = container.shape
    for i in range(1, size[0] - 1):
        for j in range(1, size[1] - 1):
            gx = (img[i - 1][j - 1] + 2*img[i][j - 1] + img[i + 1][j - 1]) - (img[i - 1][j + 1] + 2*img[i][j + 1] + img[i + 1][j + 1])
            gy = (img[i - 1][j - 1] + 2*img[i - 1][j] + img[i - 1][j + 1]) - (img[i + 1][j - 1] + 2*img[i + 1][j] + img[i + 1][j + 1])
            
            
            container[i][j] = min(255, np.sqrt(gx**2 + gy**2))
    return container
    pass

img = cv2.cvtColor(cv2.imread("lkjsampel.jpg"), cv2.COLOR_BGR2GRAY)
img = sobelOperator(img)
img_before = copy.deepcopy(img)
img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)

print("Gambar Original")
plt.imshow(img_original)
plt.show()

print("Gambar Setelah diproses")
plt.imshow(img)
plt.show()
# Out:
# Gambar Original
# Gambar Setelah diproses

# %%
#matrik pada Gambar Original
#print(img_original)

# %%
#Matrix Image Yg sudah diproses
#print(img)

# %%
#img_before = img
jawab = []
for i in range(0, len(img_before)):
    for j in range(0, len(img_before[i])):
        if j == 12 and i == 20:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("A")
                print("Nomor 1 Jawaban A")
        if j == 26 and i == 20:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("B")
                print("Nomor 1 Jawaban B")
        if j == 41 and i == 20:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("C")
                print("Nomor 1 Jawaban C")
        if j == 55 and i == 20:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("D")
                print("Nomor 1 Jawaban D")
        if j == 68 and i == 20:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("E")
                print("Nomor 1 Jawaban E")
                
                
        if j == 12 and i == 38:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("A")
                print("Nomor 2 Jawaban A")
        if j == 26 and i == 38:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("B")
                print("Nomor 2 Jawaban B")
        if j == 41 and i == 38:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("C")
                print("Nomor 2 Jawaban C")
        if j == 55 and i == 38:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("D")
                print("Nomor 2 Jawaban D")
        if j == 68 and i == 38:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("E")
                print("Nomor 2 Jawaban E")
                
                
        if j == 12 and i == 56:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("A")
                print("Nomor 3 Jawaban A")
        if j == 26 and i == 56:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("B")
                print("Nomor 3 Jawaban B")
        if j == 41 and i == 56:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("C")
                print("Nomor 3 Jawaban C")
        if j == 55 and i == 56:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("D")
                print("Nomor 3 Jawaban D")
        if j == 68 and i == 56:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("E")
                print("Nomor 3 Jawaban E")
                
                
        if j == 12 and i == 76:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("A")
                print("Nomor 4 Jawaban A")
        if j == 26 and i == 76:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("B")
                print("Nomor 4 Jawaban B")
        if j == 41 and i == 76:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("C")
                print("Nomor 4 Jawaban C")
        if j == 55 and i == 76:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("D")
                print("Nomor 4 Jawaban D")
        if j == 68 and i == 76:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("E")
                print("Nomor 4 Jawaban E")
                
                
        if j == 12 and i == 92:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("A")
                print("Nomor 5 Jawaban A")
        if j == 26 and i == 92:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("B")
                print("Nomor 5 Jawaban B")
        if j == 41 and i == 92:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("C")
                print("Nomor 5 Jawaban C")
        if j == 55 and i == 92:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("D")
                print("Nomor 5 Jawaban D")
        if j == 68 and i == 92:
            #img_before[i,j]=255
            if(img_before[i,j] >= 200 ):
                jawab.append("E")
                print("Nomor 5 Jawaban E")
            
        
        
                   

#print(jawab[0])
# plt.imshow(img_before)
# plt.show()




#img_before[i,j]=0
# np.set_printoptions(threshold=np.inf)
# print(img_before)
# Out:
# Nomor 1 Jawaban A
# Nomor 2 Jawaban C
# Nomor 3 Jawaban B
# Nomor 4 Jawaban E
# Nomor 5 Jawaban C

# %%
# Perhitungan Nilai Akhir

koreksi = ["A", "C", "C", "D", "E"]


for i in range (0, len(jawab)):
    if (jawab[i] == koreksi[i]):
        betul + 1
            
nilai = (betul/5)*100

print(nilai)


# print(koreksi[1])
# print(len(jawab))
# Out:
# 80.0
